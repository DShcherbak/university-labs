# %% [markdown]
# <a href="https://colab.research.google.com/github/DShcherbak/University_Labs/blob/main/semester-7/neural-networks/lectures/lecture-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
np.set_printoptions(precision=2)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c12d94c4-02a8-42f3-a940-38dabc04885e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c12d94c4-02a8-42f3-a940-38dabc04885e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving beauty.csv to beauty.csv
# {'beauty.csv': b'wage;exper;union;goodhlth;black;female;married;service;educ;looks\n5.73;30;0;1;0;1;1;1;14;4\n4.28;28;0;1;0;1;1;0;12;3\n7.96;35;0;1;0;1;0;0;10;4\n11.57;38;0;1;0;0;1;1;16;3\n11.42;27;0;1;0;0;1;0;16;3\n3.91;20;0;0;0;1;1;0;12;3\n8.76;12;0;1;0;0;1;0;16;3\n7.69;5;1;1;0;0;0;0;16;4\n5;5;0;1;0;1;0;0;16;3\n3.89;12;0;1;0;1;0;0;12;3\n3.45;3;0;1;0;1;0;0;12;4\n4.03;6;0;1;0;0;1;0;16;4\n5.14;19;0;1;0;0;1;1;17;2\n3;8;0;1;0;0;0;1;16;3\n7.99;12;0;1;0;0;1;0;16;4\n6.01;17;0;1;0;0;1;0;16;4\n5.16;7;0;1;0;0;1;0;17;3\n11.54;12;0;1;0;0;1;1;17;4\n10.44;10;0;1;0;1;0;0;17;4\n7.69;7;0;1;0;1;1;1;16;3\n7.69;7;1;1;0;0;0;0;17;4\n6.79;19;0;1;0;0;1;1;14;3\n6.87;33;0;1;0;0;1;1;12;3\n17.03;32;0;1;0;0;1;0;13;3\n10.05;12;0;1;0;0;1;0;13;4\n15.81;24;0;1;0;0;1;1;17;4\n14.84;29;0;1;0;0;0;1;13;5\n19.08;17;0;1;0;0;0;0;17;5\n8.35;41;0;0;0;0;1;1;16;1\n9.62;40;0;0;0;0;1;0;16;3\n5.96;10;0;1;0;0;1;0;14;3\n5.73;43;0;0;0;0;1;0;10;3\n6.73;41;0;1;0;0;1;0;10;4\n8.17;18;0;1;0;0;1;0;16;2\n12.39;28;0;1;0;0;1;0;12;4\n9.62;37;0;1;0;0;1;0;13;2\n4.83;20;0;1;1;0;1;0;16;4\n7.69;10;1;1;0;0;1;0;13;2\n12.5;31;0;1;0;0;1;0;16;3\n2.82;18;0;1;0;0;1;1;12;3\n12.31;9;1;1;0;0;0;0;17;3\n13.22;42;0;1;0;0;1;0;16;3\n16.83;14;0;1;0;0;1;0;16;4\n11.54;27;0;1;0;0;1;0;16;3\n4.95;20;0;1;1;1;0;1;14;3\n7.21;14;0;1;0;0;1;0;17;3\n11.58;4;0;1;0;0;1;0;17;3\n15.38;13;0;1;0;0;1;0;17;3\n6.1;5;0;1;0;0;1;1;17;3\n7.93;32;0;1;0;0;1;1;17;3\n9.16;19;1;1;0;1;1;1;17;4\n6.91;14;0;1;0;1;0;1;17;4\n20.18;28;0;1;0;0;1;1;17;3\n9.93;31;1;1;0;0;1;0;17;3\n7.79;18;0;1;0;0;1;0;13;4\n5.13;23;0;1;0;0;1;1;5;3\n10.99;14;0;1;0;0;1;0;16;4\n6.56;17;0;1;0;0;1;0;13;2\n10.1;16;0;1;0;0;1;0;13;3\n10.74;19;0;1;0;0;1;0;16;3\n16.35;26;0;1;0;0;1;0;17;3\n4.62;20;0;1;0;1;1;1;12;4\n7.49;18;0;1;0;0;1;0;17;3\n19.23;35;0;1;0;0;1;0;17;3\n4.77;9;0;1;0;1;0;1;17;4\n7.14;20;0;1;0;1;0;1;17;2\n14.42;7;0;1;0;0;1;1;17;4\n9.28;40;0;1;0;0;0;1;17;4\n29.98;12;0;1;0;0;1;1;17;3\n32.79;33;0;1;0;0;1;1;16;4\n9.62;16;0;1;0;0;1;0;16;3\n8.36;15;0;1;0;1;1;0;16;3\n21.63;11;0;1;0;0;1;1;17;3\n15.9;24;0;1;0;0;1;1;17;4\n5.77;6;0;1;0;0;1;1;17;2\n20.99;40;0;1;0;0;1;1;17;2\n23.32;15;0;1;0;0;1;1;17;5\n4.97;9;0;1;0;0;1;1;17;4\n6.89;16;0;1;0;0;1;0;17;2\n5.73;12;0;1;0;1;0;1;13;2\n5.19;8;0;1;0;0;1;1;17;3\n7.79;25;1;1;0;1;0;1;17;3\n8.79;24;1;1;0;1;1;1;16;3\n9.32;25;1;1;0;1;0;0;17;4\n8.33;7;0;1;0;1;0;1;17;4\n10.12;40;0;1;1;1;0;1;10;3\n1.98;29;0;0;0;1;0;1;8;3\n8.24;13;0;1;0;1;1;1;17;4\n5.05;5;0;1;0;1;0;1;14;4\n6.55;10;0;1;0;1;1;0;16;3\n4.47;25;1;1;0;0;1;1;13;3\n7.96;10;0;1;0;1;1;1;16;3\n6.25;20;0;1;0;0;0;1;17;2\n4.13;7;0;1;0;0;0;0;16;3\n6.73;25;0;1;0;1;1;1;13;2\n7.69;8;0;1;0;1;0;1;17;3\n4.35;8;0;1;0;1;1;1;14;2\n7.69;28;0;1;0;0;1;0;14;3\n4.81;37;0;1;0;0;1;1;16;2\n5.24;31;0;1;0;0;1;1;17;3\n2.14;24;0;1;0;0;1;1;16;4\n4.49;33;0;1;0;0;1;1;17;4\n3.61;8;0;1;0;0;1;1;17;4\n5.45;33;0;1;0;0;1;1;17;3\n5;30;0;1;0;0;1;1;17;3\n6.73;23;0;1;0;0;1;1;17;3\n10.05;24;0;1;0;0;1;0;16;3\n6.54;4;0;1;0;0;1;0;17;4\n9.2;40;0;1;0;1;0;1;17;3\n4.62;1;0;1;0;1;0;1;16;3\n3.37;36;0;1;1;1;0;1;13;3\n5.54;7;0;1;0;1;0;1;17;4\n6.11;7;0;1;0;1;1;0;12;5\n4.99;14;0;1;0;1;0;1;13;3\n5.88;7;0;1;0;1;1;1;17;3\n5.66;11;1;1;0;1;0;1;16;4\n4;6;0;1;0;0;1;1;16;3\n6.87;23;0;1;0;1;1;1;16;3\n4.37;19;0;1;0;1;0;1;17;2\n5.77;30;0;1;0;0;1;0;13;3\n5.77;21;0;1;0;0;1;1;17;4\n12.31;9;0;1;0;0;1;1;17;4\n19.08;29;1;1;0;0;1;1;17;3\n7.55;9;0;1;0;1;0;1;17;3\n5.9;18;0;1;0;1;0;1;17;4\n6.37;26;0;1;0;1;0;1;17;3\n6.15;21;1;1;0;0;1;1;17;4\n1.92;12;1;1;0;1;1;1;17;2\n3.27;11;0;1;0;0;0;1;17;3\n2.18;18;0;1;0;0;0;1;17;4\n5.62;22;0;1;0;0;1;1;17;3\n9.29;38;0;1;0;1;0;1;17;4\n6.41;10;1;1;0;1;1;1;17;3\n7.46;22;1;1;0;1;1;1;16;3\n6.59;16;1;1;0;1;0;1;17;2\n6.73;20;1;1;0;1;1;1;17;2\n5.61;14;1;1;0;1;1;1;16;3\n3.65;14;0;1;0;1;1;1;16;4\n13.01;15;1;1;0;0;1;1;17;4\n6.97;18;1;1;0;0;0;1;17;3\n7.69;21;1;1;0;1;1;1;17;3\n6.73;15;0;1;0;0;1;1;16;3\n5.13;10;1;1;0;1;0;1;17;3\n2.14;6;0;1;0;1;1;1;16;4\n4.53;8;1;1;0;1;1;1;14;2\n9.1;18;0;1;0;1;0;1;17;2\n9.78;15;1;1;0;1;0;1;17;3\n3.63;11;0;1;0;1;1;1;13;4\n7.21;20;1;0;1;1;1;1;17;3\n10.62;18;1;1;0;1;1;1;17;3\n4.62;10;1;1;0;1;1;1;17;3\n6.54;26 ...

# %%
data = pd.read_csv('beauty.csv', sep=';')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
data.shape
# Out:
# (1260, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   wage      1260 non-null   float64
#  1   exper     1260 non-null   int64
#  2   union     1260 non-null   int64
#  3   goodhlth  1260 non-null   int64
#  4   black     1260 non-null   int64
#  5   female    1260 non-null   int64
#  6   married   1260 non-null   int64
#  7   service   1260 non-null   int64
#  8   educ      1260 non-null   int64
#  9   looks     1260 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 98.6 KB

# %%
data.describe()
# Out:
#               wage        exper  ...         educ        looks
# count  1260.000000  1260.000000  ...  1260.000000  1260.000000
# mean      6.306690    18.206349  ...    12.563492     3.185714
# std       4.660639    11.963485  ...     2.624489     0.684877
# min       1.020000     0.000000  ...     5.000000     1.000000
# 25%       3.707500     8.000000  ...    12.000000     3.000000
# 50%       5.300000    15.000000  ...    12.000000     3.000000
# 75%       7.695000    27.000000  ...    13.000000     4.000000
# max      77.720000    48.000000  ...    17.000000     5.000000
#
# [8 rows x 10 columns]

# %%
data['exper'].head()
# Out:
# 0    30
# 1    28
# 2    35
# 3    38
# 4    27
# Name: exper, dtype: int64

# %%
data.loc[0:5, ['wage', 'female']]
# Out:
#     wage  female
# 0   5.73       1
# 1   4.28       1
# 2   7.96       1
# 3  11.57       0
# 4  11.42       0
# 5   3.91       1

# %%
data.iloc[:, 2:4]
# Out:
#       union  goodhlth
# 0         0         1
# 1         0         1
# 2         0         1
# 3         0         1
# 4         0         1
# ...     ...       ...
# 1255      0         1
# 1256      0         1
# 1257      0         1
# 1258      0         1
# 1259      0         0
#
# [1260 rows x 2 columns]

# %%
data[data["female"]==1]["wage"].mean(), data[data["female"]==0]["wage"].mean()
# Out:
# (4.299357798165136, 7.3688228155339734)

# %%
data[(data["female"] == 0) & (data["married"] == 1)]["wage"].median(), \
data[(data["female"] == 0) & (data["married"] == 0)]["wage"].median()
# Out:
# (6.710000000000001, 5.0649999999999995)

# %%
 for look, sub_df in data.groupby("looks"):
        print(look)
        print(sub_df["female"].mean())
# Out:
# 1
# 0.38461538461538464
# 2
# 0.38028169014084506
# 3
# 0.32271468144044324
# 4
# 0.37362637362637363
# 5
# 0.42105263157894735

# %%
data.groupby("looks")[['wage', 'exper']].agg(np.median)
# Out:
#         wage  exper
# looks
# 1      3.460   32.0
# 2      4.595   18.0
# 3      5.635   18.0
# 4      5.240   12.5
# 5      4.810    8.0

# %%
pd.crosstab(data['female'], data['married'])
# Out:
# married    0    1
# female
# 0        166  658
# 1        223  213

# %%
pd.crosstab(data['female'], data['looks'])
# Out:
# looks   1   2    3    4   5
# female
# 0       8  88  489  228  11
# 1       5  54  233  136   8

# %%
data['is_rich'] = (data['wage'] > data['wage'].quantile(.75)).astype('int64')
data.head()
# Out:
#     wage  exper  union  goodhlth  black  ...  married  service  educ  looks  is_rich
# 0   5.73     30      0         1      0  ...        1        1    14      4        0
# 1   4.28     28      0         1      0  ...        1        0    12      3        0
# 2   7.96     35      0         1      0  ...        0        0    10      4        1
# 3  11.57     38      0         1      0  ...        1        1    16      3        1
# 4  11.42     27      0         1      0  ...        1        0    16      3        1
#
# [5 rows x 11 columns]

# %%
data['rubbish'] = .56 * data['wage'] + 0.32 * data['exper']

def string_gender(female):
  return 'female' if female else 'male'

# %%
d = {1 : 'union', 0: 'non-union'}

data['union'].map(d).head()
# Out:
# 0    non-union
# 1    non-union
# 2    non-union
# 3    non-union
# 4    non-union
# Name: union, dtype: object

# %%
data['female'].apply(lambda x : string_gender(x)).head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: female, dtype: object
